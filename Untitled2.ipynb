# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
repo = '/home/rneveux/to_emulator_diag_kcut/with_f/cosmo_0'

# %%
for ell in ['000','202']:
    fichier = np.load(repo+'/'+ell+'/tree/b1_b1_b1.npy',allow_pickle=True).item()
    plt.plot(fichier['kbin'],fichier['kbin']**2*fichier['K'])

# %%
for ell in ['000','202']:
    fichier = np.load(repo+'/'+ell+'/tree/b1_f_f.npy',allow_pickle=True).item()
    plt.plot(fichier['kbin'],fichier['kbin']**2*fichier['K'])

# %%
for ell in ['000','202']:
    fichier = np.load(repo+'/'+ell+'/tree/b1_b1_b2.npy',allow_pickle=True).item()
    plt.plot(fichier['kbin'],fichier['kbin']**2*fichier['K'])

# %%
for kernel in ['b1_b1_b1','b1_b1_b2']:
    fichier = np.load(repo+'/'+'202'+'/tree/'+kernel+'.npy',allow_pickle=True).item()
    plt.plot(fichier['kbin'],fichier['kbin']**2*fichier['K'])

# %%
for i in ['Bshot_b1_b1', 'Bshot_b1_f', 'Bshot_b1_c1', 'Bshot_b1_c2','Pshot_f_b1', 
     'Pshot_f_f', 'Pshot_f_c1', 'Pshot_f_c2']:
    fichier = np.load(repo+'/000/SN/{}.npy'.format(i),allow_pickle=True).item()
    plt.plot(fichier['kbin'],fichier['kbin']**2*fichier['K'])
    plt.show()
